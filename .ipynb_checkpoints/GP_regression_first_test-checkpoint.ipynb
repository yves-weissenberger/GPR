# %%
# %matplotlib inline


from __future__ import division

import numpy as np

import time, re, os, sys
import copy as cp

import matplotlib.pyplot as plt
import seaborn
from scipy.stats import multivariate_normal
import scipy.spatial.distance as dst
seaborn.set_context("paper",font_scale=2)
seaborn.set_style("whitegrid")


kernel = lambda x1,x2: k*np.exp((-.5)*((x1-x2)**2)/l**2)

# %%
n_samps = 20
x_samples = np.linspace(1,5,num=n_samps)

# %%
SIGMA = np.zeros([n_samps,n_samps])

# %%
#define parameters for the GP regression
k = 3
l = .5

# %%
distances = []
dist_MTX = np.zeros([n_samps,n_samps])
for idx1,samp1 in enumerate(x_samples):
    
    for idx2,samp2 in enumerate(x_samples):
        
        distances.append(samp1-samp2)
        dist_MTX[idx1,idx2] = np.abs(samp1-samp2)
        SIGMA[idx1,idx2] = kernel(samp1,samp2)  #+= 1e-6
        #if idx1==idx2:
        #    SIGMA[idx1,idx2]
            
SIGMA += np.eye(SIGMA.shape[0])*1e-6

# %%
for idx1,samp1 in enumerate(x_samples):
    
    for idx2,samp2 in enumerate(x_samples):
        
        dist_MTX[idx1,idx2] = np.abs(samp1-samp2)

# %%
dist_MTX
# Out:
# array([[ 0.        ,  0.21052632,  0.42105263,  0.63157895,  0.84210526,
#          1.05263158,  1.26315789,  1.47368421,  1.68421053,  1.89473684,
#          2.10526316,  2.31578947,  2.52631579,  2.73684211,  2.94736842,
#          3.15789474,  3.36842105,  3.57894737,  3.78947368,  4.        ],
#        [ 0.21052632,  0.        ,  0.21052632,  0.42105263,  0.63157895,
#          0.84210526,  1.05263158,  1.26315789,  1.47368421,  1.68421053,
#          1.89473684,  2.10526316,  2.31578947,  2.52631579,  2.73684211,
#          2.94736842,  3.15789474,  3.36842105,  3.57894737,  3.78947368],
#        [ 0.42105263,  0.21052632,  0.        ,  0.21052632,  0.42105263,
#          0.63157895,  0.84210526,  1.05263158,  1.26315789,  1.47368421,
#          1.68421053,  1.89473684,  2.10526316,  2.31578947,  2.52631579,
#          2.73684211,  2.94736842,  3.15789474,  3.36842105,  3.57894737],
#        [ 0.63157895,  0.42105263,  0.21052632,  0.        ,  0.21052632,
#          0.42105263,  0.63157895,  0.84210526,  1.05263158,  1.26315789,
#          1.47368421,  1.68421053,  1.89473684,  2.10526316,  2.31578947,
#          2.52631579,  2.73684211,  2.94736842,  3.15789474,  3.36842105],
#        [ 0.84210526,  0.63157895,  0.42105263,  0.21052632,  0.        ,
#          0.21052632,  0.42105263,  0.63157895,  0.84210526,  1.05263158,
#          1.26315789,  1.47368421,  1.68421053,  1.89473684,  2.10526316,
#          2.31578947,  2.52631579,  2.73684211,  2.94736842,  3.15789474],
#        [ 1.05263158,  0.84210526,  0.63157895,  0.42105263,  0.21052632,
#          0.        ,  0.21052632,  0.42105263,  0.63157895,  0.84210526,
#        [ 3.15789474,  2.94736842,  2.73684211,  2.52631579,  2.31578947,
#          2.10526316,  1.89473684,  1.68421053,  1.47368421,  1.26315789,
#          1.05263158,  0.84210526,  0.63157895,  0.42105263,  0.21052632,
#          0.        ,  0.21052632,  0.42105263,  0.63157895,  0.84210526],
#        [ 3.36842105,  3.15789474,  2.94736842,  2.73684211,  2.52631579,
#          2.31578947,  2.10526316,  1.89473684,  1.68421053,  1.47368421,
#          1.26315789,  1.05263158,  0.84210526,  0.63157895,  0.42105263,
#          0.21052632,  0.        ,  0.21052632,  0.42105263,  0.63157895],
#        [ 3.57894737,  3.36842105,  3.15789474,  2.94736842,  2.73684211,
#          2.52631579,  2.31578947,  2.10526316,  1.89473684,  1.68421053,
#          1.47368421,  1.26315789,  1.05263158,  0.84210526,  0.63157895,
#          0.42105263,  0.21052632,  0.        ,  0.21052632,  0.42105263],
#        [ 3.78947368,  3.57894737,  3.36842105,  3.15789474,  2.94736842,
#          2.73684211,  2.52631579,  2.31578947,  2.10526316,  1.89473684,
#          1.68421053,  1.47368421,  1.26315789,  1.05263158,  0.84210526,
#          0.63157895,  0.42105263,  0.21052632,  0.        ,  0.21052632],
#        [ 4.        ,  3.78947368,  3.57894737,  3.36842105,  3.15789474,
#          2.94736842,  2.73684211,  2.52631579,  2.31578947,  2.10526316,
#          1.89473684,  1.68421053,  1.47368421,  1.26315789,  1.05263158,
#          0.84210526,  0.63157895,  0.42105263,  0.21052632,  0.        ]])

# %%
ar = dst.pdist(np.vstack([x_samples,x_samples]).T,metric='euclidean')[0]

# %%
plt.imshow(dist_MTX)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x12c8086c8>

# %%
plt.imshow(dst.squareform(dst.pdist(np.vstack([x_samples,x_samples]).T,metric='euclidean')))
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x144845638>

# %%
plt.imshow(dist_MTX)

# %%
plt.imshow(SIGMA)

# %%
dst.squareform(distances)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1574-6631ea333bf6> in <module>()
# ----> 1 dst.squareform(distances)
#
# /usr/local/lib/python2.7/site-packages/scipy/spatial/distance.pyc in squareform(X, force, checks)
#    1465         # Check that v is of valid dimensions.
#    1466         if d * (d - 1) / 2 != int(s[0]):
# -> 1467             raise ValueError('Incompatible vector size. It must be a binomial '
#    1468                              'coefficient n choose 2 for some integer n >= 2.')
#    1469
#
# ValueError: Incompatible vector size. It must be a binomial coefficient n choose 2 for some integer n >= 2.

# %%
np.random.random()
# Out:
# 0.1817059661793763

# %%
mu = np.zeros(n_samps)

# %%
mvn = multivariate_normal(mu,cov=SIGMA)

# %%
plt.imshow(SIGMA,interpolation='none')
plt.grid()
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1203e5290>

# %%
for i in range(1):
    plt.plot(x_samples,mvn.rvs(),'o')

# %% [markdown]
# ## Plot  a Bunch of Samples from the prior distribution

# %%
for i in range(10):
    plt.plot(x_samples,mvn.rvs())

# %% [markdown]
# #
#
# $f∗|X∗, X,f ∼ \mathcal{N}(
# K(X∗, X)K(X, X)^{−1}f,
# K(X∗, X∗) − K(X∗, X)K(X, X)^{−1}K(X, X∗))
#
# .$
#
# $p(x|m, Σ) = (2π)
# −D/2
# |Σ|
# −1/2
# exp^{−\frac{1}{2}(x − m)'Σ^{−1}(x − m)}$

# %%
#D = np.array([[3,.1],[4,.1],[5,.1],[40,2],[80,-4]])
xs = np.linspace(0.01,10,num=300)
ys = np.sin(.5*np.pi*xs)*3 + np.sin(2*np.pi*xs) + (1/np.exp(xs/2))*6*np.sin(4*np.pi*xs) + xs//2
#ys = (1/np.exp(xs/2))*4*np.sin(2*np.pi*xs) + xs/2
#ys = np.hstack([np.zeros(50),np.ones(50)*2]) - 1
plt.plot(xs,ys)

D = np.vstack([xs,ys+np.random.normal(scale=1,size=xs.shape)]).T

plt.plot(xs,D[:,1])

n_samps = 220
x_samples = np.linspace(0,10,num=n_samps)

# %%
plt.plot(1/np.exp(xs))

# %%
#define parameters for the GP regression
k = 2
l = 1e-1

# %%
K = np.zeros([D.shape[0],D.shape[0]])


for idx1,samp1 in enumerate(D[:,0]):
    
    for idx2,samp2 in enumerate(D[:,0]):
        
        K[idx1,idx2] = kernel(samp1,samp2)  #+= 1e-6
        #if idx1==idx2:
K += 2*np.eye(D.shape[0])



Kst =  np.zeros([x_samples.shape[0],D.shape[0]])


for idx1,samp1 in enumerate(x_samples):
    
    for idx2,samp2 in enumerate(D[:,0]):
        
        Kst[idx1,idx2] = kernel(samp1,samp2)  #+= 1e-6
        #if idx1==idx2:


Kstst =  np.zeros([x_samples.shape[0],x_samples.shape[0]])


for idx1,samp1 in enumerate(x_samples):
    
    for idx2,samp2 in enumerate(x_samples):
        
        Kstst[idx1,idx2] = kernel(samp1,samp2)  #+= 1e-6
        #if idx1==idx2:

# %%
GP_mean = Kst.dot(np.linalg.inv(K)).dot(D[:,1])

# %%
GP_cov = (Kstst - Kst.dot(np.linalg.inv(K)).dot(Kst.T)) + np.eye(GP_mean.shape[0])*1e-6

# %%
GP_posterior = multivariate_normal(GP_mean,GP_cov)

# %% [markdown]
# #  This is success enjoy the beautiful plot of samples from the posterior

# %%
plt.figure(figsize=(12,6))

ax = plt.gca()

#for i in range(4):
#    ax.plot(x_samples,GP_posterior.rvs())
    
#ax.plot(x_samples,GP_posterior.rvs(),label='Posterior Samples')


ax.plot(x_samples,GP_mean,linewidth=2,color='k',label='Posterior Mean')



ax.fill_between(x_samples, GP_mean-np.sqrt(np.diag(GP_cov)), GP_mean+np.sqrt(np.diag(GP_cov)), facecolor=[.3]*3,alpha=.4, interpolate=True,label='CI')
ax.plot([0], [0], color=[.3]*3,alpha=.4,linewidth=12, label='$\pm$2SD')


ax.plot(D[:,0],ys,color=[.9,.4,.9],linestyle='--',linewidth=4,label='True Function')
ax.scatter(D[:,0],D[:,1],s=64,color=[.8,.3,.2])

ax.legend(loc='best')
plt.xlabel(r'$x$')
plt.ylabel(r'$f(x)$')
plt.xlim(xmin=0,xmax=6.3)
# Out:
# (0, 6.3)

# %% [markdown]
# ## Samples From Posterior Distribution of Functions

# %%
for idx1,samp1 in enumerate(x_samples):
    
    for idx2,samp2 in enumerate(x_samples):
        
        
        SIGMA[idx1,idx2] = kernel(samp1,samp2)  #+= 1e-6
        #if idx1==idx2:
        #    SIGMA[idx1,idx2]
            
SIGMA += np.eye(SIGMA.shape[0])*1e-6

mu = np.zeros(x_samples.shape)
GP_prior = multivariate_normal(mu,cov=SIGMA)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1500-18c4c7d738c8> in <module>()
#       4
#       5
# ----> 6         SIGMA[idx1,idx2] = kernel(samp1,samp2)  #+= 1e-6
#       7         #if idx1==idx2:
#       8         #    SIGMA[idx1,idx2]
#
# IndexError: index 20 is out of bounds for axis 1 with size 20

# %%
plt.figure(figsize=(16,8))
plt.suptitle('Samples from Distributions of GP \n\n')

plt.subplot(1,2,1)
plt.title('Samples From Prior')
ax = plt.gca()
for i in range(3):
    ax.plot(x_samples,mvn.rvs())
    
ax.plot(x_samples,mvn.rvs(),label='Samples')
plt.xlabel(r'$x$')
plt.ylabel(r'$f(x)$')


plt.subplot(1,2,2)
ax = plt.gca()
plt.title('\nSamples From Posterior')
for i in range(3):
    ax.plot(x_samples,GP_posterior.rvs())
    
ax.plot(x_samples,GP_posterior.rvs(),label='Samples')
plt.xlabel(r'$x$')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1501-69a51a17cb42> in <module>()
#       6 ax = plt.gca()
#       7 for i in range(3):
# ----> 8     ax.plot(x_samples,mvn.rvs())
#       9
#      10 ax.plot(x_samples,mvn.rvs(),label='Samples')
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1371         lines = []
#    1372
# -> 1373         for line in self._get_lines(*args, **kwargs):
#    1374             self.add_line(line)
#    1375             lines.append(line)
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _grab_next_args(self, *args, **kwargs)
#     302                 return
#     303             if len(remaining) <= 3:
# --> 304                 for seg in self._plot_args(remaining, kwargs):
#     305                     yield seg
#     306                 return
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _plot_args(self, tup, kwargs)
#     280             x = np.arange(y.shape[0], dtype=float)
#     281
# --> 282         x, y = self._xy_from_xy(x, y)
#     283
#     284         if self.command == 'plot':
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _xy_from_xy(self, x, y)
#     221         y = np.atleast_1d(y)
#     222         if x.shape[0] != y.shape[0]:
# --> 223             raise ValueError("x and y must have same first dimension")
#     224         if x.ndim > 2 or y.ndim > 2:
#     225             raise ValueError("x and y can be no greater than 2-D")
#
# ValueError: x and y must have same first dimension

# %% [markdown]
# # Repeat Procedure in 2D

# %%
n_samps = 100
x_pos = np.linspace(1,5,num=n_samps)
y_pos = np.linspace(3,5,num=n_samps)

# %%
kernel = lambda x1,x2: k*np.exp((-.5)*((x1-x2)**2)/l**2)

# %%
SIGMA = np.zeros([n_samps,n_samps])

# %%
#define parameters for the GP regression
k = 3
l = .5

# %%
for idx1,samp1 in enumerate(x_samples):
    
    for idx2,samp2 in enumerate(x_samples):
        
        
        SIGMA[idx1,idx2] = kernel(samp1,samp2)  #+= 1e-6
        #if idx1==idx2:
        #    SIGMA[idx1,idx2]
            
SIGMA += np.eye(SIGMA.shape[0])*1e-6
